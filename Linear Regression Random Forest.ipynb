# %%
import pandas as pd
import numpy as np
import matplotlib as plt
df = pd.read_csv("hack_ru.csv")
df
# Out:
#        Unnamed: 0            country     company  total_pack_size_ml_g  \
# 0               0            Vietnam     Brand 0                130.00
# 1               1             Brazil     Brand 1                 90.00
# 2               2            Vietnam     Brand 2                120.00
# 3               3                 UK     Brand 3                100.00
# 4               4           Thailand     Brand 4                160.00
# 5               5           Thailand     Brand 5                124.00
# 6               6           Thailand     Brand 6                125.00
# 7               7          Argentina     Brand 0                 75.00
# 8               8             Israel     Brand 7                 75.00
# 9               9       Saudi Arabia     Brand 1                 75.00
# 10             10            Austria     Brand 0                 75.00
# 11             11            Austria     Brand 8                 75.00
# ...

# %%
reformmat
for x in df["ingredients"]:
# Out:
#   File "<ipython-input-2-ed433b403eac>", line 1
#     for x in df["ingredients"]:
#                                ^
# SyntaxError: unexpected EOF while parsing
