# %%
from amazon.api import AmazonAPI
amazon = AmazonAPI('AKIAJPQQLYH7HCM7LREQ', 'zaFhP+qGmESyhsQ1gCbXHOAIN3wTf+BswGywpbNZ', 'luthriaworks-20', Region='IN')
products = amazon.lookup(ItemId='B00KC6I06S,B005DOK8NW,B00TSUGXKE')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-2-d713884b2764> in <module>
#       1 from amazon.api import AmazonAPI
#       2 amazon = AmazonAPI('AKIAJPQQLYH7HCM7LREQ', 'zaFhP+qGmESyhsQ1gCbXHOAIN3wTf+BswGywpbNZ', 'luthriaworks-20', Region='IN')
# ----> 3 products = amazon.lookup(ItemId='B00KC6I06S,B005DOK8NW,B00TSUGXKE')
#
# ~/anaconda3/lib/python3.7/site-packages/amazon/api.py in lookup(self, ResponseGroup, **kwargs)
#     172             items where returned.
#     173         """
# --> 174         response = self.api.ItemLookup(ResponseGroup=ResponseGroup, **kwargs)
#     175         root = objectify.fromstring(response)
#     176         if root.Items.Request.IsValid == 'False':
#
# ~/anaconda3/lib/python3.7/site-packages/bottlenose/api.py in __call__(self, **kwargs)
#     272         # make the actual API call
# ...

# %%
import requests

url = "http://api-prd.axesso.de/amz/amazon-search-by-keyword?keyword=Playstation4&domainCode=com&sortBy=date-desc-rank&page=1"

headers = {
    'x-rapidapi-host': "axesso-axesso-amazon-data-service-v1.p.rapidapi.com",
    'x-rapidapi-key': "4vB59oWlqGmsh8ojOArDODrvo9fKp1hGN3ojsnJeIOXsP621LQ"
    }

response = requests.request("GET", url, headers=headers)

print(response.text)
# Out:
# [{"logref":"error","message":"Full authentication is required to access this resource","links":[]}]

# %%
import http.client

conn = http.client.HTTPSConnection("axesso-axesso-amazon-data-service-v1.p.rapidapi.com")

headers = {
    'x-rapidapi-host': "axesso-axesso-amazon-data-service-v1.p.rapidapi.com",
    'x-rapidapi-key': "4vB59oWlqGmsh8ojOArDODrvo9fKp1hGN3ojsnJeIOXsP621LQ"
    }

conn.request("GET", "/amz/amazon-search-by-keyword?keyword=couch&domainCode=com&sortBy=date-desc-rank&page=1", headers=headers)

res = conn.getresponse()
data = res.read()

string = data.decode("utf-8")

# %%
import json    # or `import simplejson as json` if on Python < 2.6
import http.client

def get_price(string):

conn = http.client.HTTPSConnection("axesso-axesso-amazon-data-service-v1.p.rapidapi.com")

headers = {
    'x-rapidapi-host': "axesso-axesso-amazon-data-service-v1.p.rapidapi.com",
    'x-rapidapi-key': "4vB59oWlqGmsh8ojOArDODrvo9fKp1hGN3ojsnJeIOXsP621LQ"
    }

conn.request("GET", "/amz/amazon-search-by-keyword?keyword=couch&domainCode=com&sortBy=date-desc-rank&page=1", headers=headers)

res = conn.getresponse()
data = res.read()

string = data.decode("utf-8")
    json_string = string
    obj = json.loads(json_string)   
    for x in obj['foundProductDetails']:
        if x['responseStatus'] =="PRODUCT_FOUND_RESPONSE":
            if x["price"]>0.0:
                return (x["price"], x["productTitle"])
        return (0.0, "n/a")
# Out:
# 549.0

# %%
obj
# Out:
# {'responseStatus': 'PRODUCT_FOUND_RESPONSE',
#  'responseMessage': 'Product successfully found!',
#  'sortStrategy': 'date-desc-rank',
#  'domainCode': 'com',
#  'keyword': 'couch',
#  'numberOfProducts': 10,
#  'resultCount': 932,
#  'foundProductDetails': [{'responseStatus': 'PRODUCT_FOUND_RESPONSE',
#    'responseMessage': 'Product successfully found!',
#    'productTitle': 'Romatlink Sectional Sofa Couch, Modern L Shape Sectional, Sofa Couch with Chaise,Upholstered in Soft Linen Fabric on a Hardwood Frame for Small/Large Living Spaces, Furniture Sectionals',
#    'manufacturer': 'romatlink',
#    'countReview': 0,
#    'answeredQuestions': 0,
#    'productRating': None,
#    'asin': 'B07Z9CQ95J',
#    'sizeSelection': [],
#    'soldBy': 'Amazon',
#    'fulfilledBy': 'Amazon',
#    'warehouseAvailability': 'Usually ships within 2 to 3 days.',
#    'retailPrice': 0.0,
#    'price': 549.0,
#    'priceShippingInformation': '& FREE Shipping. Details',
#    'priceSaving': None,
# ...
